# %%
import time
import random
import numpy as np
from collections import deque
import tensorflow as tf
from matplotlib import pyplot as plt


class DQNAgent:
    """ DQN agent """
    def __init__(self, states, actions, max_memory, double_q):
        self.states = states
        self.actions = actions
        self.session = tf.Session()
        self.build_model()
        self.saver = tf.train.Saver(max_to_keep=10)
        self.session.run(tf.global_variables_initializer())
        self.saver = tf.train.Saver()
        self.memory = deque(maxlen=max_memory)
        self.eps = 1
        self.eps_decay = 0.99999975
        self.eps_min = 0.1
        self.gamma = 0.90
        self.batch_size = 32
        self.burnin = 100000
        self.copy = 10000
        self.step = 0
        self.learn_each = 3
        self.learn_step = 0
        self.save_each = 500000
        self.double_q = double_q

    def build_model(self):
        """ Model builder function """
        self.input = tf.placeholder(dtype=tf.float32, shape=(None, ) + self.states, name='input')
        self.q_true = tf.placeholder(dtype=tf.float32, shape=[None], name='labels')
        self.a_true = tf.placeholder(dtype=tf.int32, shape=[None], name='actions')
        self.reward = tf.placeholder(dtype=tf.float32, shape=[], name='reward')
        self.input_float = tf.to_float(self.input) / 255.
        # Online network
        with tf.variable_scope('online'):
            self.conv_1 = tf.layers.conv2d(inputs=self.input_float, filters=32, kernel_size=8, strides=4, activation=tf.nn.relu)
            self.conv_2 = tf.layers.conv2d(inputs=self.conv_1, filters=64, kernel_size=4, strides=2, activation=tf.nn.relu)
            self.conv_3 = tf.layers.conv2d(inputs=self.conv_2, filters=64, kernel_size=3, strides=1, activation=tf.nn.relu)
            self.flatten = tf.layers.flatten(inputs=self.conv_3)
            self.dense = tf.layers.dense(inputs=self.flatten, units=512, activation=tf.nn.relu)
            self.output = tf.layers.dense(inputs=self.dense, units=self.actions, name='output')
        # Target network
        with tf.variable_scope('target'):
            self.conv_1_target = tf.layers.conv2d(inputs=self.input_float, filters=32, kernel_size=8, strides=4, activation=tf.nn.relu)
            self.conv_2_target = tf.layers.conv2d(inputs=self.conv_1_target, filters=64, kernel_size=4, strides=2, activation=tf.nn.relu)
            self.conv_3_target = tf.layers.conv2d(inputs=self.conv_2_target, filters=64, kernel_size=3, strides=1, activation=tf.nn.relu)
            self.flatten_target = tf.layers.flatten(inputs=self.conv_3_target)
            self.dense_target = tf.layers.dense(inputs=self.flatten_target, units=512, activation=tf.nn.relu)
            self.output_target = tf.stop_gradient(tf.layers.dense(inputs=self.dense_target, units=self.actions, name='output_target'))
        # Optimizer
        self.action = tf.argmax(input=self.output, axis=1)
        self.q_pred = tf.gather_nd(params=self.output, indices=tf.stack([tf.range(tf.shape(self.a_true)[0]), self.a_true], axis=1))
        self.loss = tf.losses.huber_loss(labels=self.q_true, predictions=self.q_pred)
        self.train = tf.train.AdamOptimizer(learning_rate=0.00025).minimize(self.loss)
        # Summaries
        self.summaries = tf.summary.merge([
            tf.summary.scalar('reward', self.reward),
            tf.summary.scalar('loss', self.loss),
            tf.summary.scalar('max_q', tf.reduce_max(self.output))
        ])
        self.writer = tf.summary.FileWriter(logdir='./logs', graph=self.session.graph)

    def copy_model(self):
        """ Copy weights to target network """
        self.session.run([tf.assign(new, old) for (new, old) in zip(tf.trainable_variables('target'), tf.trainable_variables('online'))])

    def save_model(self):
        """ Saves current model to disk """
        self.saver.save(sess=self.session, save_path='./models/model', global_step=self.step)

    def add(self, experience):
        """ Add observation to experience """
        self.memory.append(experience)

    def predict(self, model, state):
        """ Prediction """
        if model == 'online':
            return self.session.run(fetches=self.output, feed_dict={self.input: np.array(state)})
        if model == 'target':
            return self.session.run(fetches=self.output_target, feed_dict={self.input: np.array(state)})

    def run(self, state):
        """ Perform action """
        if np.random.rand() < self.eps:
            # Random action
            action = np.random.randint(low=0, high=self.actions)
        else:
            # Policy action
            q = self.predict('online', np.expand_dims(state, 0))
            action = np.argmax(q)
        # Decrease eps
        self.eps *= self.eps_decay
        self.eps = max(self.eps_min, self.eps)
        # Increment step
        self.step += 1
        return action

    def learn(self):
        """ Gradient descent """
        # Sync target network
        if self.step % self.copy == 0:
            self.copy_model()
        # Checkpoint model
        if self.step % self.save_each == 0:
            self.save_model()
        # Break if burn-in
        if self.step < self.burnin:
            return
        # Break if no training
        if self.learn_step < self.learn_each:
            self.learn_step += 1
            return
        # Sample batch
        batch = random.sample(self.memory, self.batch_size)
        state, next_state, action, reward, done = map(np.array, zip(*batch))
        # Get next q values from target network
        next_q = self.predict('target', next_state)
        # Calculate discounted future reward
        if self.double_q:
            q = self.predict('online', next_state)
            a = np.argmax(q, axis=1)
            target_q = reward + (1. - done) * self.gamma * next_q[np.arange(0, self.batch_size), a]
        else:
            target_q = reward + (1. - done) * self.gamma * np.amax(next_q, axis=1)
        # Update model
        summary, _ = self.session.run(fetches=[self.summaries, self.train],
                                      feed_dict={self.input: state,
                                                 self.q_true: np.array(target_q),
                                                 self.a_true: np.array(action),
                                                 self.reward: np.mean(reward)})
        # Reset learn step
        self.learn_step = 0
        # Write
        self.writer.add_summary(summary, self.step)

    def replay(self, env, model_path, n_replay, plot):
        """ Model replay """
        ckpt = tf.train.latest_checkpoint(model_path)
        saver = tf.train.import_meta_graph(ckpt + '.meta')
        graph = tf.get_default_graph()
        input = graph.get_tensor_by_name('input:0')
        output = graph.get_tensor_by_name('online/output/BiasAdd:0')
        # Replay RL agent
        state = env.reset()
        total_reward = 0
        with tf.Session() as sess:
            saver.restore(sess, ckpt)
            for _ in range(n_replay):
                step = 0
                while True:
                    time.sleep(0.05)
                    env.render()
                    # Plot
                    if plot:
                        if step % 100 == 0:
                            self.visualize_layer(session=sess, layer=self.conv_2, state=state, step=step)
                    # Action
                    if np.random.rand() < 0.0:
                        action = np.random.randint(low=0, high=self.actions, size=1)[0]
                    else:
                        q = sess.run(fetches=output, feed_dict={input: np.expand_dims(state, 0)})
                        action = np.argmax(q)
                    next_state, reward, done, info = env.step(action)
                    total_reward += reward
                    state = next_state
                    step += 1
                    if info['flag_get']:
                        break
                    if done:
                        break
        env.close()

    def visualize_layer(self, session, layer, state, step):
        """ Visualization auf Conv Layers"""
        units = session.run(layer, feed_dict={self.input: np.expand_dims(state, 0)})
        filters = units.shape[3]
        plt.figure(1, figsize=(40, 40))
        n_columns = 8
        n_rows = np.ceil(filters / n_columns)
        for i in range(filters):
            plt.subplot(n_rows, n_columns, i+1)
            plt.title('Filter ' + str(i))
            plt.imshow(units[0, :, :, i], interpolation="nearest", cmap='YlGnBu')
        plt.savefig(fname='./img/img-' + str(step) + '.png')

# %%
# Mostly copy-pasted from https://github.com/openai/baselines/blob/master/baselines/common/atari_wrappers.py
import numpy as np
import os
os.environ.setdefault('PATH', '')
from collections import deque
import gym
from gym import spaces
import cv2
cv2.ocl.setUseOpenCL(False)


class NoopResetEnv(gym.Wrapper):
    def __init__(self, env, noop_max=30):
        """Sample initial states by taking random number of no-ops on reset.
        No-op is assumed to be action 0.
        """
        gym.Wrapper.__init__(self, env)
        self.noop_max = noop_max
        self.override_num_noops = None
        self.noop_action = 0
        assert env.unwrapped.get_action_meanings()[0] == 'NOOP'

    def reset(self, **kwargs):
        """ Do no-op action for a number of steps in [1, noop_max]."""
        self.env.reset(**kwargs)
        if self.override_num_noops is not None:
            noops = self.override_num_noops
        else:
            noops = self.unwrapped.np_random.randint(1, self.noop_max + 1) #pylint: disable=E1101
        assert noops > 0
        obs = None
        for _ in range(noops):
            obs, _, done, _ = self.env.step(self.noop_action)
            if done:
                obs = self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)


class FireResetEnv(gym.Wrapper):
    def __init__(self, env):
        """Take action on reset for environments that are fixed until firing."""
        gym.Wrapper.__init__(self, env)
        assert env.unwrapped.get_action_meanings()[1] == 'FIRE'
        assert len(env.unwrapped.get_action_meanings()) >= 3

    def reset(self, **kwargs):
        self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(1)
        if done:
            self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(2)
        if done:
            self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)


class EpisodicLifeEnv(gym.Wrapper):
    def __init__(self, env):
        """Make end-of-life == end-of-episode, but only reset on true game over.
        Done by DeepMind for the DQN and co. since it helps value estimation.
        """
        gym.Wrapper.__init__(self, env)
        self.lives = 0
        self.was_real_done  = True

    def step(self, action):
        obs, reward, done, info = self.env.step(action)
        self.was_real_done = done
        # check current lives, make loss of life terminal,
        # then update lives to handle bonus lives
        lives = self.env.unwrapped.ale.lives()
        if lives < self.lives and lives > 0:
            # for Qbert sometimes we stay in lives == 0 condition for a few frames
            # so it's important to keep lives > 0, so that we only reset once
            # the environment advertises done.
            done = True
        self.lives = lives
        return obs, reward, done, info

    def reset(self, **kwargs):
        """Reset only when lives are exhausted.
        This way all states are still reachable even though lives are episodic,
        and the learner need not know about any of this behind-the-scenes.
        """
        if self.was_real_done:
            obs = self.env.reset(**kwargs)
        else:
            # no-op step to advance from terminal/lost life state
            obs, _, _, _ = self.env.step(0)
        self.lives = self.env.unwrapped.ale.lives()
        return obs


class MaxAndSkipEnv(gym.Wrapper):
    def __init__(self, env, skip=4):
        """Return only every `skip`-th frame"""
        gym.Wrapper.__init__(self, env)
        # most recent raw observations (for max pooling across time steps)
        self._obs_buffer = np.zeros((2,)+env.observation_space.shape, dtype=np.uint8)
        self._skip = skip

    def step(self, action):
        """Repeat action, sum reward, and max over last observations."""
        total_reward = 0.0
        done = None
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            if i == self._skip - 2: self._obs_buffer[0] = obs
            if i == self._skip - 1: self._obs_buffer[1] = obs
            total_reward += reward
            if done:
                break
        # Note that the observation on the done=True frame
        # doesn't matter
        max_frame = self._obs_buffer.max(axis=0)

        return max_frame, total_reward, done, info

    def reset(self, **kwargs):
        return self.env.reset(**kwargs)


class ClipRewardEnv(gym.RewardWrapper):
    def __init__(self, env):
        gym.RewardWrapper.__init__(self, env)

    def reward(self, reward):
        """Bin reward to {+1, 0, -1} by its sign."""
        return np.sign(reward)


class WarpFrame(gym.ObservationWrapper):
    def __init__(self, env, width=84, height=84, grayscale=True):
        """Warp frames to 84x84 as done in the Nature paper and later work."""
        gym.ObservationWrapper.__init__(self, env)
        self.width = width
        self.height = height
        self.grayscale = grayscale
        if self.grayscale:
            self.observation_space = spaces.Box(low=0, high=255,
                shape=(self.height, self.width, 1), dtype=np.uint8)
        else:
            self.observation_space = spaces.Box(low=0, high=255,
                shape=(self.height, self.width, 3), dtype=np.uint8)

    def observation(self, frame):
        if self.grayscale:
            frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(frame, (self.width, self.height), interpolation=cv2.INTER_AREA)
        if self.grayscale:
            frame = np.expand_dims(frame, -1)
        return frame


class LazyFrames(object):
    def __init__(self, frames):
        """This object ensures that common frames between the observations are only stored once.
        It exists purely to optimize memory usage which can be huge for DQN's 1M frames replay
        buffers.
        This object should only be converted to numpy array before being passed to the model.
        You'd not believe how complex the previous solution was."""
        self._frames = frames
        self._out = None

    def _force(self):
        if self._out is None:
            self._out = np.concatenate(self._frames, axis=-1)
            self._frames = None
        return self._out

    def __array__(self, dtype=None):
        out = self._force()
        if dtype is not None:
            out = out.astype(dtype)
        return out

    def __len__(self):
        return len(self._force())

    def __getitem__(self, i):
        return self._force()[i]


class FrameStack(gym.Wrapper):
    def __init__(self, env, k):
        """Stack k last frames.
        Returns lazy array, which is much more memory efficient.
        See Also
        --------
        baselines.common.atari_wrappers.LazyFrames
        """
        gym.Wrapper.__init__(self, env)
        self.k = k
        self.frames = deque([], maxlen=k)
        shp = env.observation_space.shape
        self.observation_space = spaces.Box(low=0, high=255, shape=(shp[:-1] + (shp[-1] * k,)), dtype=env.observation_space.dtype)

    def reset(self):
        ob = self.env.reset()
        for _ in range(self.k):
            self.frames.append(ob)
        return self._get_ob()

    def step(self, action):
        ob, reward, done, info = self.env.step(action)
        self.frames.append(ob)
        return self._get_ob(), reward, done, info

    def _get_ob(self):
        assert len(self.frames) == self.k
        return LazyFrames(list(self.frames))


def wrapper(env):
    """Apply a common set of wrappers for Atari games."""
    #env = EpisodicLifeEnv(env)
    #env = NoopResetEnv(env, noop_max=10)
    env = MaxAndSkipEnv(env, skip=4)
    if 'FIRE' in env.unwrapped.get_action_meanings():
       env = FireResetEnv(env)
    env = WarpFrame(env)
    env = FrameStack(env, 4)
    env = ClipRewardEnv(env)
    return env

# %%
# Configuration paramaters for the whole setup
import time
import numpy as np
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

seed = 42
gamma = 0.99  # Discount factor for past rewards
epsilon = 1.0  # Epsilon greedy parameter
epsilon_min = 0.05  # Minimum epsilon greedy parameter
epsilon_max = 1.0  # Maximum epsilon greedy parameter
epsilon_interval = (
    epsilon_max - epsilon_min
)  # Rate at which to reduce chance of random action being taken
batch_size = 32  # Size of batch taken from replay buffer
max_steps_per_episode = 1000

# Use the Baseline Atari environment because of Deepmind helper functions
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env=JoypadSpace(env,SIMPLE_MOVEMENT)
# Warp the frames, grey scale, stake four frame and scale to smaller ratio
env = wrapper(env)
env.seed(seed)

num_actions = 4


def create_q_model():
    # Network defined by the Deepmind paper
    inputs = layers.Input(shape=(84, 84, 4,))

    # Convolutions on the frames on the screen
    layer1 = layers.Conv2D(32, 8, strides=4, activation="relu")(inputs)
    layer2 = layers.Conv2D(64, 4, strides=2, activation="relu")(layer1)
    layer3 = layers.Conv2D(64, 3, strides=1, activation="relu")(layer2)
    layer4 = layers.Conv2D(64, 3, strides=1, activation="relu")(layer3)
    layer5 = layers.Conv2D(64, 3, strides=1, activation="relu")(layer4)

    layer6 = layers.Flatten()(layer5)

    layer7 = layers.Dense(256, activation="relu")(layer6)
    #layer8 = layers.Dense(64, activation="relu")(layer7)
    action = layers.Dense(num_actions, activation="linear")(layer7)

    return keras.Model(inputs=inputs, outputs=action)


# The first model makes the predictions for Q-values which are used to
# make a action.
model = create_q_model()
model.summary()
# Build a target model for the prediction of future rewards.
# The weights of a target model get updated every 10000 steps thus when the
# loss between the Q-values is calculated the target Q-value is stable.
model_target = create_q_model()

# In the Deepmind paper they use RMSProp however then Adam optimizer
# improves training time
optimizer = keras.optimizers.Adam(learning_rate=0.00025, clipnorm=1.0)

# Experience replay buffers
action_history = []
state_history = []
state_next_history = []
rewards_history = []
done_history = []
episode_reward_history = []
running_reward = 0
episode_count = 0
frame_count = 0
# Number of frames to take random action and observe output
epsilon_random_frames = 5000
# Number of frames for exploration
epsilon_greedy_frames = 100000.0
# Maximum replay length
# Note: The Deepmind paper suggests 1000000 however this causes memory issues
max_memory_length = 10000
# Train the model after 4 actions
update_after_actions = 4
# How often to update the target network
update_target_network = 1000
# Using huber loss for stability
loss_function = keras.losses.Huber()
solved = False

while True:  # Run until solved
    state = np.array(env.reset())
    episode_reward = 0

    for timestep in range(1, max_steps_per_episode):
        if solved: env.render() # Adding this line would show the attempts
        # of the agent in a pop up window.
        frame_count += 1

        # Use epsilon-greedy for exploration
        if frame_count < epsilon_random_frames or epsilon > np.random.rand(1)[0]:
            # Take random action
            action = np.random.choice(num_actions)
        else:
            # Predict action Q-values
            # From environment state
            state_tensor = tf.convert_to_tensor(state)
            state_tensor = tf.expand_dims(state_tensor, 0)
            action_probs = model(state_tensor, training=False)
            # Take best action
            action = tf.argmax(action_probs[0]).numpy()

        # Decay probability of taking random action
        epsilon -= epsilon_interval / epsilon_greedy_frames
        epsilon = max(epsilon, epsilon_min)

        # Apply the sampled action in our environment
        state_next, reward, done, _ = env.step(action)
        state_next = np.array(state_next)

        episode_reward += reward

        # Save actions and states in replay buffer
        action_history.append(action)
        state_history.append(state)
        state_next_history.append(state_next)
        done_history.append(done)
        rewards_history.append(reward)
        state = state_next

        # Update every fourth frame and once batch size is over 32
        if frame_count % update_after_actions == 0 and len(done_history) > batch_size:

            # Get indices of samples for replay buffers
            indices = np.random.choice(range(len(done_history)), size=batch_size)

            # Using list comprehension to sample from replay buffer
            state_sample = np.array([state_history[i] for i in indices])
            state_next_sample = np.array([state_next_history[i] for i in indices])
            rewards_sample = [rewards_history[i] for i in indices]
            action_sample = [action_history[i] for i in indices]
            done_sample = tf.convert_to_tensor(
                [float(done_history[i]) for i in indices]
            )

            # Build the updated Q-values for the sampled future states
            # Use the target model for stability
            future_rewards = model_target.predict(state_next_sample)
            # Q value = reward + discount factor * expected future reward
            updated_q_values = rewards_sample + gamma * tf.reduce_max(
                future_rewards, axis=1
            )

            # If final frame set the last value to -1
            updated_q_values = updated_q_values * (1 - done_sample) - done_sample

            # Create a mask so we only calculate loss on the updated Q-values
            masks = tf.one_hot(action_sample, num_actions)

            with tf.GradientTape() as tape:
                # Train the model on the states and updated Q-values
                q_values = model(state_sample)

                # Apply the masks to the Q-values to get the Q-value for action taken
                q_action = tf.reduce_sum(tf.multiply(q_values, masks), axis=1)
                # Calculate loss between new Q-value and old Q-value
                loss = loss_function(updated_q_values, q_action)

            # Backpropagation
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))

        if frame_count % update_target_network == 0:
            # update the the target network with new weights
            model_target.set_weights(model.get_weights())
            # Log details
            template = "running reward: {:.2f} at episode {}, frame count {}"
            print(template.format(running_reward, episode_count, frame_count))

        # Limit the state and reward history
        if len(rewards_history) > max_memory_length:
            del rewards_history[:1]
            del state_history[:1]
            del state_next_history[:1]
            del action_history[:1]
            del done_history[:1]

        if done:
            break

    print("frame_count="+str(frame_count)+" epsilon="+str(epsilon)+" episode_reward="+str(episode_reward)+" running_reward="+str(running_reward))

    # Update running reward to check condition for solving
    episode_reward_history.append(episode_reward)
    if len(episode_reward_history) > 100:
        del episode_reward_history[:1]
    running_reward = np.mean(episode_reward_history)

    episode_count += 1

    if solved == False or running_reward > 40:  # Condition to consider the task solved
        print("Solved at episode {}!".format(episode_count))
        #break
        solved = True
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 84, 84, 4)]       0
#
#  conv2d (Conv2D)             (None, 20, 20, 32)        8224
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 64)          32832
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          36928
#
#  conv2d_3 (Conv2D)           (None, 5, 5, 64)          36928
#
#  conv2d_4 (Conv2D)           (None, 3, 3, 64)          36928
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 256)               147712
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 300,580
# Trainable params: 300,580
# Non-trainable params: 0
# _________________________________________________________________
# frame_count=689 epsilon=0.993454500000003 episode_reward=133.0 running_reward=0
# Solved at episode 1!
# running reward: 133.00 at episode 1, frame count 1000
# frame_count=1688 epsilon=0.9839640000000074 episode_reward=51.0 running_reward=133.0
# Solved at episode 2!
# running reward: 92.00 at episode 2, frame count 2000
# frame_count=2687 epsilon=0.9744735000000118 episode_reward=-23.0 running_reward=92.0
# Solved at episode 3!
# running reward: 53.67 at episode 3, frame count 3000
# frame_count=3686 epsilon=0.9649830000000161 episode_reward=-90.0 running_reward=53.666666666666664
# frame_count=3997 epsilon=0.9620285000000175 episode_reward=209.0 running_reward=17.75
# Solved at episode 5!
# running reward: 56.00 at episode 5, frame count 4000
# frame_count=4327 epsilon=0.9588935000000189 episode_reward=183.0 running_reward=56.0
# Solved at episode 6!
# running reward: 77.17 at episode 6, frame count 5000
# frame_count=5326 epsilon=0.9494030000000233 episode_reward=-52.0 running_reward=77.16666666666667
# Solved at episode 7!
# running reward: 58.71 at episode 7, frame count 6000
# frame_count=6325 epsilon=0.9399125000000277 episode_reward=-81.0 running_reward=58.714285714285715
# Solved at episode 8!
# frame_count=6612 epsilon=0.9371860000000289 episode_reward=182.0 running_reward=41.25
# Solved at episode 9!
# frame_count=6715 epsilon=0.9362075000000294 episode_reward=93.0 running_reward=56.888888888888886
# Solved at episode 10!
# frame_count=6816 epsilon=0.9352480000000298 episode_reward=92.0 running_reward=60.5
# Solved at episode 11!
# running reward: 63.36 at episode 11, frame count 7000
# frame_count=7815 epsilon=0.9257575000000342 episode_reward=-44.0 running_reward=63.36363636363637
# Solved at episode 12!
# running reward: 54.42 at episode 12, frame count 8000
# frame_count=8046 epsilon=0.9235630000000352 episode_reward=158.0 running_reward=54.416666666666664
# Solved at episode 13!
# frame_count=8988 epsilon=0.9146140000000393 episode_reward=104.0 running_reward=62.38461538461539
# Solved at episode 14!
# running reward: 65.36 at episode 14, frame count 9000
# frame_count=9987 epsilon=0.9051235000000437 episode_reward=-89.0 running_reward=65.35714285714286
# Solved at episode 15!
# running reward: 55.07 at episode 15, frame count 10000
# frame_count=10605 epsilon=0.8992525000000464 episode_reward=158.0 running_reward=55.06666666666667
# Solved at episode 16!
# running reward: 61.50 at episode 16, frame count 11000
# frame_count=11604 epsilon=0.8897620000000508 episode_reward=-97.0 running_reward=61.5
# Solved at episode 17!
# frame_count=11896 epsilon=0.8869880000000521 episode_reward=205.0 running_reward=52.1764705882353
# Solved at episode 18!
# running reward: 60.67 at episode 18, frame count 12000
# frame_count=12895 epsilon=0.8774975000000564 episode_reward=-91.0 running_reward=60.666666666666664
# Solved at episode 19!
# running reward: 52.68 at episode 19, frame count 13000
# frame_count=13894 epsilon=0.8680070000000608 episode_reward=8.0 running_reward=52.68421052631579
# Solved at episode 20!
# running reward: 50.45 at episode 20, frame count 14000
# frame_count=14893 epsilon=0.8585165000000652 episode_reward=-10.0 running_reward=50.45
# Solved at episode 21!
# running reward: 47.57 at episode 21, frame count 15000
# frame_count=15623 epsilon=0.8515815000000684 episode_reward=82.0 running_reward=47.57142857142857
# Solved at episode 22!
# frame_count=15728 epsilon=0.8505840000000688 episode_reward=92.0 running_reward=49.13636363636363
# Solved at episode 23!
# running reward: 51.00 at episode 23, frame count 16000
# frame_count=16727 epsilon=0.8410935000000732 episode_reward=-100.0 running_reward=51.0
# Solved at episode 24!
# running reward: 44.71 at episode 24, frame count 17000
# frame_count=17726 epsilon=0.8316030000000776 episode_reward=-55.0 running_reward=44.708333333333336
# Solved at episode 25!
# frame_count=17851 epsilon=0.8304155000000781 episode_reward=116.0 running_reward=40.72
# Solved at episode 26!
# running reward: 43.62 at episode 26, frame count 18000
# frame_count=18850 epsilon=0.8209250000000825 episode_reward=34.0 running_reward=43.61538461538461
# Solved at episode 27!
# running reward: 43.26 at episode 27, frame count 19000
# frame_count=19849 epsilon=0.8114345000000869 episode_reward=18.0 running_reward=43.25925925925926
# Solved at episode 28!
# running reward: 42.36 at episode 28, frame count 20000
# frame_count=20848 epsilon=0.8019440000000913 episode_reward=17.0 running_reward=42.357142857142854
# Solved at episode 29!
# running reward: 41.48 at episode 29, frame count 21000
# frame_count=21263 epsilon=0.7980015000000931 episode_reward=257.0 running_reward=41.48275862068966
# Solved at episode 30!
# frame_count=21547 epsilon=0.7953035000000943 episode_reward=184.0 running_reward=48.666666666666664
# Solved at episode 31!
# running reward: 53.03 at episode 31, frame count 22000
# frame_count=22546 epsilon=0.7858130000000987 episode_reward=10.0 running_reward=53.03225806451613
# Solved at episode 32!
# frame_count=22659 epsilon=0.7847395000000992 episode_reward=99.0 running_reward=51.6875
# Solved at episode 33!
# running reward: 53.12 at episode 33, frame count 23000
# frame_count=23658 epsilon=0.7752490000001035 episode_reward=11.0 running_reward=53.121212121212125
# Solved at episode 34!
# running reward: 51.88 at episode 34, frame count 24000
# frame_count=24657 epsilon=0.7657585000001079 episode_reward=24.0 running_reward=51.88235294117647
# Solved at episode 35!
# running reward: 51.09 at episode 35, frame count 25000
# frame_count=25579 epsilon=0.756999500000112 episode_reward=98.0 running_reward=51.08571428571429
# Solved at episode 36!
# running reward: 52.39 at episode 36, frame count 26000
# frame_count=26059 epsilon=0.7524395000001141 episode_reward=156.0 running_reward=52.388888888888886
# Solved at episode 37!
# running reward: 55.19 at episode 37, frame count 27000
# frame_count=27058 epsilon=0.7429490000001184 episode_reward=-78.0 running_reward=55.189189189189186
# Solved at episode 38!
# frame_count=27390 epsilon=0.7397950000001199 episode_reward=164.0 running_reward=51.68421052631579
# Solved at episode 39!
# frame_count=27582 epsilon=0.7379710000001207 episode_reward=160.0 running_reward=54.56410256410256
# Solved at episode 40!
# running reward: 57.20 at episode 40, frame count 28000
# frame_count=28581 epsilon=0.7284805000001251 episode_reward=29.0 running_reward=57.2
# Solved at episode 41!
# running reward: 56.51 at episode 41, frame count 29000
# frame_count=29096 epsilon=0.7235880000001274 episode_reward=205.0 running_reward=56.51219512195122
# Solved at episode 42!
# running reward: 60.05 at episode 42, frame count 30000
# frame_count=30095 epsilon=0.7140975000001317 episode_reward=224.0 running_reward=60.04761904761905
# Solved at episode 43!
# frame_count=30519 epsilon=0.7100695000001336 episode_reward=199.0 running_reward=63.86046511627907
# Solved at episode 44!
# running reward: 66.93 at episode 44, frame count 31000
# frame_count=31518 epsilon=0.700579000000138 episode_reward=-63.0 running_reward=66.93181818181819
# Solved at episode 45!
# running reward: 64.04 at episode 45, frame count 32000
# frame_count=32086 epsilon=0.6951830000001404 episode_reward=135.0 running_reward=64.04444444444445
# Solved at episode 46!
# frame_count=32189 epsilon=0.6942045000001409 episode_reward=96.0 running_reward=65.58695652173913
# Solved at episode 47!
# frame_count=32673 epsilon=0.689606500000143 episode_reward=143.0 running_reward=66.23404255319149
# Solved at episode 48!
# running reward: 67.83 at episode 48, frame count 33000
# frame_count=33255 epsilon=0.6840775000001456 episode_reward=227.0 running_reward=67.83333333333333
# Solved at episode 49!
# frame_count=33666 epsilon=0.6801730000001474 episode_reward=186.0 running_reward=71.08163265306122
# Solved at episode 50!
# running reward: 73.38 at episode 50, frame count 34000
# frame_count=34665 epsilon=0.6706825000001517 episode_reward=163.0 running_reward=73.38
# Solved at episode 51!
# running reward: 75.14 at episode 51, frame count 35000
# frame_count=35664 epsilon=0.6611920000001561 episode_reward=15.0 running_reward=75.13725490196079
# Solved at episode 52!
# running reward: 73.98 at episode 52, frame count 36000
# frame_count=36591 epsilon=0.6523855000001602 episode_reward=158.0 running_reward=73.98076923076923
# Solved at episode 53!
# frame_count=36985 epsilon=0.6486425000001619 episode_reward=158.0 running_reward=75.56603773584905
# Solved at episode 54!
# running reward: 77.09 at episode 54, frame count 37000
# frame_count=37553 epsilon=0.6432465000001644 episode_reward=224.0 running_reward=77.0925925925926
# Solved at episode 55!
# running reward: 79.76 at episode 55, frame count 38000
# frame_count=38552 epsilon=0.6337560000001687 episode_reward=-75.0 running_reward=79.76363636363637
# Solved at episode 56!
# frame_count=38650 epsilon=0.6328250000001692 episode_reward=89.0 running_reward=77.0
# Solved at episode 57!
# frame_count=38907 epsilon=0.6303835000001703 episode_reward=162.0 running_reward=77.21052631578948
# Solved at episode 58!
# running reward: 78.67 at episode 58, frame count 39000
# frame_count=39906 epsilon=0.6208930000001747 episode_reward=135.0 running_reward=78.67241379310344
# Solved at episode 59!
# running reward: 79.63 at episode 59, frame count 40000
# frame_count=40152 epsilon=0.6185560000001757 episode_reward=161.0 running_reward=79.62711864406779
# Solved at episode 60!
# running reward: 80.98 at episode 60, frame count 41000
# frame_count=41151 epsilon=0.6090655000001801 episode_reward=-66.0 running_reward=80.98333333333333
# Solved at episode 61!
# frame_count=41380 epsilon=0.6068900000001811 episode_reward=152.0 running_reward=78.57377049180327
# Solved at episode 62!
# frame_count=41679 epsilon=0.6040495000001824 episode_reward=175.0 running_reward=79.75806451612904
# Solved at episode 63!
# frame_count=41802 epsilon=0.602881000000183 episode_reward=106.0 running_reward=81.26984126984127
# Solved at episode 64!
# running reward: 81.66 at episode 64, frame count 42000
# frame_count=42455 epsilon=0.5966775000001858 episode_reward=236.0 running_reward=81.65625
# Solved at episode 65!
# running reward: 84.03 at episode 65, frame count 43000
# frame_count=43454 epsilon=0.5871870000001902 episode_reward=152.0 running_reward=84.03076923076924
# Solved at episode 66!
# running reward: 85.06 at episode 66, frame count 44000
# frame_count=44453 epsilon=0.5776965000001946 episode_reward=1.0 running_reward=85.06060606060606
# Solved at episode 67!
# frame_count=44688 epsilon=0.5754640000001956 episode_reward=131.0 running_reward=83.80597014925372
# Solved at episode 68!
# frame_count=44817 epsilon=0.5742385000001962 episode_reward=117.0 running_reward=84.5
# Solved at episode 69!
# running reward: 84.97 at episode 69, frame count 45000
# frame_count=45816 epsilon=0.5647480000002005 episode_reward=-27.0 running_reward=84.97101449275362
# Solved at episode 70!
# running reward: 83.37 at episode 70, frame count 46000
# frame_count=46705 epsilon=0.5563025000002044 episode_reward=72.0 running_reward=83.37142857142857
# Solved at episode 71!
# running reward: 83.21 at episode 71, frame count 47000
# frame_count=47704 epsilon=0.5468120000002088 episode_reward=8.0 running_reward=83.21126760563381
# Solved at episode 72!
# frame_count=47914 epsilon=0.5448170000002097 episode_reward=173.0 running_reward=82.16666666666667
# Solved at episode 73!
# running reward: 83.41 at episode 73, frame count 48000
# frame_count=48182 epsilon=0.5422710000002109 episode_reward=191.0 running_reward=83.41095890410959
# Solved at episode 74!
# frame_count=48454 epsilon=0.5396870000002121 episode_reward=106.0 running_reward=84.86486486486487
# Solved at episode 75!
# running reward: 85.15 at episode 75, frame count 49000
# frame_count=49453 epsilon=0.5301965000002165 episode_reward=-50.0 running_reward=85.14666666666666
# Solved at episode 76!
# running reward: 83.37 at episode 76, frame count 50000
# frame_count=50452 epsilon=0.5207060000002208 episode_reward=23.0 running_reward=83.36842105263158
# Solved at episode 77!
# running reward: 82.58 at episode 77, frame count 51000
# frame_count=51451 epsilon=0.5112155000002252 episode_reward=78.0 running_reward=82.58441558441558
# Solved at episode 78!
# running reward: 82.53 at episode 78, frame count 52000
# frame_count=52233 epsilon=0.5037865000002286 episode_reward=468.0 running_reward=82.52564102564102
# Solved at episode 79!
# frame_count=52670 epsilon=0.49963500000023053 episode_reward=232.0 running_reward=87.40506329113924
# Solved at episode 80!
# running reward: 89.21 at episode 80, frame count 53000
# frame_count=53669 epsilon=0.4901445000002349 episode_reward=109.0 running_reward=89.2125
# Solved at episode 81!
# running reward: 89.46 at episode 81, frame count 54000
# frame_count=54008 epsilon=0.4869240000002364 episode_reward=180.0 running_reward=89.45679012345678
# Solved at episode 82!
# running reward: 90.56 at episode 82, frame count 55000
# frame_count=55007 epsilon=0.47743350000024076 episode_reward=42.0 running_reward=90.5609756097561
# Solved at episode 83!
# frame_count=55107 epsilon=0.4764835000002412 episode_reward=91.0 running_reward=89.97590361445783
# Solved at episode 84!
# frame_count=55323 epsilon=0.47443150000024215 episode_reward=159.0 running_reward=89.98809523809524
# Solved at episode 85!
# running reward: 90.80 at episode 85, frame count 56000
# frame_count=56322 epsilon=0.4649410000002465 episode_reward=-90.0 running_reward=90.8
# Solved at episode 86!
# running reward: 88.70 at episode 86, frame count 57000
# frame_count=57008 epsilon=0.4584240000002495 episode_reward=115.0 running_reward=88.69767441860465
# Solved at episode 87!
# frame_count=57243 epsilon=0.45619150000025055 episode_reward=156.0 running_reward=89.0
# Solved at episode 88!
# frame_count=57510 epsilon=0.4536550000002517 episode_reward=188.0 running_reward=89.76136363636364
# Solved at episode 89!
# running reward: 90.87 at episode 89, frame count 58000
# frame_count=58509 epsilon=0.4441645000002561 episode_reward=-13.0 running_reward=90.86516853932584
# Solved at episode 90!
# frame_count=58672 epsilon=0.4426160000002568 episode_reward=138.0 running_reward=89.71111111111111
# Solved at episode 91!
# frame_count=58960 epsilon=0.43988000000025806 episode_reward=210.0 running_reward=90.24175824175825
# Solved at episode 92!
# running reward: 91.54 at episode 92, frame count 59000
# frame_count=59046 epsilon=0.43906300000025844 episode_reward=77.0 running_reward=91.54347826086956
# Solved at episode 93!
# running reward: 91.39 at episode 93, frame count 60000
# frame_count=60045 epsilon=0.4295725000002628 episode_reward=-56.0 running_reward=91.38709677419355
# Solved at episode 94!
# frame_count=60133 epsilon=0.4287365000002632 episode_reward=79.0 running_reward=89.81914893617021
# Solved at episode 95!
# frame_count=60284 epsilon=0.42730200000026386 episode_reward=118.0 running_reward=89.70526315789473
# Solved at episode 96!
# running reward: 90.00 at episode 96, frame count 61000
# frame_count=61217 epsilon=0.41843850000026794 episode_reward=23.0 running_reward=90.0
# Solved at episode 97!
# frame_count=61523 epsilon=0.4155315000002693 episode_reward=158.0 running_reward=89.30927835051547
# Solved at episode 98!
# running reward: 90.01 at episode 98, frame count 62000
# frame_count=62288 epsilon=0.40826400000027263 episode_reward=94.0 running_reward=90.01020408163265
# Solved at episode 99!
# frame_count=62429 epsilon=0.40692450000027325 episode_reward=132.0 running_reward=90.05050505050505
# Solved at episode 100!
# running reward: 90.47 at episode 100, frame count 63000
# frame_count=63266 epsilon=0.3989730000002769 episode_reward=192.0 running_reward=90.47
# Solved at episode 101!
# running reward: 91.06 at episode 101, frame count 64000
# frame_count=64086 epsilon=0.3911830000002805 episode_reward=166.0 running_reward=91.06
# Solved at episode 102!
# running reward: 92.21 at episode 102, frame count 65000
# frame_count=65085 epsilon=0.3816925000002849 episode_reward=-105.0 running_reward=92.21
# Solved at episode 103!
# frame_count=65344 epsilon=0.379232000000286 episode_reward=210.0 running_reward=91.39
# Solved at episode 104!
# frame_count=65472 epsilon=0.37801600000028657 episode_reward=117.0 running_reward=94.39
# Solved at episode 105!
# frame_count=65811 epsilon=0.37479550000028805 episode_reward=165.0 running_reward=93.47
# Solved at episode 106!
# running reward: 93.29 at episode 106, frame count 66000
# frame_count=66810 epsilon=0.3653050000002924 episode_reward=119.0 running_reward=93.29
# Solved at episode 107!
# running reward: 95.00 at episode 107, frame count 67000
# frame_count=67809 epsilon=0.3558145000002968 episode_reward=226.0 running_reward=95.0
# Solved at episode 108!
# running reward: 98.07 at episode 108, frame count 68000
# frame_count=68808 epsilon=0.34632400000030117 episode_reward=-8.0 running_reward=98.07
# Solved at episode 109!
# running reward: 96.17 at episode 109, frame count 69000
# frame_count=69210 epsilon=0.34250500000030293 episode_reward=310.0 running_reward=96.17
# Solved at episode 110!
# running reward: 98.34 at episode 110, frame count 70000
# frame_count=70018 epsilon=0.33482900000030646 episode_reward=98.0 running_reward=98.34
# Solved at episode 111!
# frame_count=70295 epsilon=0.3321975000003077 episode_reward=205.0 running_reward=98.4
# Solved at episode 112!
# frame_count=70438 epsilon=0.3308390000003083 episode_reward=133.0 running_reward=100.89
# Solved at episode 113!
# running reward: 100.64 at episode 113, frame count 71000
# frame_count=71038 epsilon=0.32513900000031093 episode_reward=321.0 running_reward=100.64
# Solved at episode 114!
# frame_count=71247 epsilon=0.32315350000031184 episode_reward=146.0 running_reward=102.81
# Solved at episode 115!
# running reward: 105.16 at episode 115, frame count 72000
# frame_count=72103 epsilon=0.3150215000003156 episode_reward=294.0 running_reward=105.16
# Solved at episode 116!
# frame_count=72335 epsilon=0.3128175000003166 episode_reward=140.0 running_reward=106.52
# Solved at episode 117!
# frame_count=72774 epsilon=0.3086470000003185 episode_reward=180.0 running_reward=108.89
# Solved at episode 118!
# running reward: 108.64 at episode 118, frame count 73000
# frame_count=73440 epsilon=0.30232000000032144 episode_reward=170.0 running_reward=108.64
# Solved at episode 119!
# frame_count=73543 epsilon=0.3013415000003219 episode_reward=92.0 running_reward=111.25
# Solved at episode 120!
# frame_count=73646 epsilon=0.30036300000032234 episode_reward=90.0 running_reward=112.09
# Solved at episode 121!
# frame_count=73994 epsilon=0.29705700000032387 episode_reward=249.0 running_reward=113.09
# Solved at episode 122!
# running reward: 114.76 at episode 122, frame count 74000
# frame_count=74301 epsilon=0.2941405000003252 episode_reward=210.0 running_reward=114.76
# Solved at episode 123!
# frame_count=74505 epsilon=0.2922025000003261 episode_reward=158.0 running_reward=115.94
# Solved at episode 124!
# frame_count=74778 epsilon=0.2896090000003273 episode_reward=235.0 running_reward=118.52
# Solved at episode 125!
# running reward: 121.42 at episode 125, frame count 75000
# frame_count=75076 epsilon=0.2867780000003286 episode_reward=163.0 running_reward=121.42
# Solved at episode 126!
# frame_count=75328 epsilon=0.2843840000003297 episode_reward=158.0 running_reward=121.89
# Solved at episode 127!
# running reward: 123.13 at episode 127, frame count 76000
# frame_count=76327 epsilon=0.2748935000003341 episode_reward=-18.0 running_reward=123.13
# Solved at episode 128!
# frame_count=76818 epsilon=0.27022900000033623 episode_reward=169.0 running_reward=122.77
# Solved at episode 129!
# frame_count=76929 epsilon=0.2691745000003367 episode_reward=101.0 running_reward=124.29
# Solved at episode 130!
# running reward: 122.73 at episode 130, frame count 77000
# frame_count=77559 epsilon=0.26318950000033947 episode_reward=259.0 running_reward=122.73
# Solved at episode 131!
# running reward: 123.48 at episode 131, frame count 78000
# frame_count=78540 epsilon=0.25387000000034377 episode_reward=87.0 running_reward=123.48
# Solved at episode 132!
# running reward: 124.25 at episode 132, frame count 79000
# frame_count=79190 epsilon=0.2476950000003466 episode_reward=213.0 running_reward=124.25
# Solved at episode 133!
# frame_count=79704 epsilon=0.24281200000034886 episode_reward=116.0 running_reward=125.39
# Solved at episode 134!
# running reward: 126.44 at episode 134, frame count 80000
# frame_count=80414 epsilon=0.23606700000035197 episode_reward=282.0 running_reward=126.44
# Solved at episode 135!
# frame_count=80574 epsilon=0.23454700000035267 episode_reward=148.0 running_reward=129.02
# Solved at episode 136!
# frame_count=80703 epsilon=0.23332150000035323 episode_reward=105.0 running_reward=129.52
# Solved at episode 137!
# frame_count=80896 epsilon=0.23148800000035408 episode_reward=177.0 running_reward=129.01
# Solved at episode 138!
# running reward: 131.56 at episode 138, frame count 81000
# frame_count=81403 epsilon=0.2266715000003563 episode_reward=140.0 running_reward=131.56
# Solved at episode 139!
# frame_count=81663 epsilon=0.22420150000035743 episode_reward=189.0 running_reward=131.32
# Solved at episode 140!
# frame_count=81803 epsilon=0.22287150000035805 episode_reward=129.0 running_reward=131.61
# Solved at episode 141!
# frame_count=81914 epsilon=0.22181700000035853 episode_reward=101.0 running_reward=132.61
# Solved at episode 142!
# running reward: 131.57 at episode 142, frame count 82000
# frame_count=82165 epsilon=0.21943250000035963 episode_reward=232.0 running_reward=131.57
# Solved at episode 143!
# frame_count=82305 epsilon=0.21810250000036024 episode_reward=98.0 running_reward=131.65
# Solved at episode 144!
# running reward: 130.64 at episode 144, frame count 83000
# frame_count=83304 epsilon=0.20861200000036462 episode_reward=19.0 running_reward=130.64
# Solved at episode 145!
# frame_count=83639 epsilon=0.20542950000036608 episode_reward=152.0 running_reward=131.46
# Solved at episode 146!
# frame_count=83831 epsilon=0.20360550000036692 episode_reward=176.0 running_reward=131.63
# Solved at episode 147!
# frame_count=83974 epsilon=0.20224700000036755 episode_reward=130.0 running_reward=132.43
# Solved at episode 148!
# running reward: 132.30 at episode 148, frame count 84000
# frame_count=84118 epsilon=0.20087900000036818 episode_reward=108.0 running_reward=132.3
# Solved at episode 149!
# frame_count=84238 epsilon=0.1997390000003687 episode_reward=109.0 running_reward=131.11
# Solved at episode 150!
# frame_count=84888 epsilon=0.19356400000037155 episode_reward=267.0 running_reward=130.34
# Solved at episode 151!
# running reward: 131.38 at episode 151, frame count 85000
# frame_count=85079 epsilon=0.19174950000037239 episode_reward=152.0 running_reward=131.38
# Solved at episode 152!
# frame_count=85201 epsilon=0.19059050000037292 episode_reward=105.0 running_reward=132.75
# Solved at episode 153!
# frame_count=85820 epsilon=0.18471000000037563 episode_reward=337.0 running_reward=132.22
# Solved at episode 154!
# running reward: 134.01 at episode 154, frame count 86000
# frame_count=86248 epsilon=0.1806440000003775 episode_reward=203.0 running_reward=134.01
# Solved at episode 155!
# frame_count=86360 epsilon=0.179580000000378 episode_reward=100.0 running_reward=133.8
# Solved at episode 156!
# frame_count=86529 epsilon=0.17797450000037873 episode_reward=127.0 running_reward=135.55
# Solved at episode 157!
# frame_count=86668 epsilon=0.17665400000037934 episode_reward=118.0 running_reward=135.93
# Solved at episode 158!
# running reward: 135.49 at episode 158, frame count 87000
# frame_count=87003 epsilon=0.1734715000003808 episode_reward=241.0 running_reward=135.49
# Solved at episode 159!
# frame_count=87149 epsilon=0.17208450000038145 episode_reward=102.0 running_reward=136.55
# Solved at episode 160!
# frame_count=87263 epsilon=0.17100150000038195 episode_reward=105.0 running_reward=135.96
# Solved at episode 161!
# running reward: 137.67 at episode 161, frame count 88000
# frame_count=88080 epsilon=0.16324000000038552 episode_reward=170.0 running_reward=137.67
# Solved at episode 162!
# frame_count=88333 epsilon=0.16083650000038663 episode_reward=163.0 running_reward=137.85
# Solved at episode 163!
# frame_count=88915 epsilon=0.15530750000038918 episode_reward=150.0 running_reward=137.73
# Solved at episode 164!
# running reward: 138.17 at episode 164, frame count 89000
# frame_count=89252 epsilon=0.15210600000039065 episode_reward=219.0 running_reward=138.17
# Solved at episode 165!
# running reward: 138.00 at episode 165, frame count 90000
# frame_count=90251 epsilon=0.14261550000039502 episode_reward=158.0 running_reward=138.0
# Solved at episode 166!
# running reward: 138.06 at episode 166, frame count 91000
# frame_count=91250 epsilon=0.1331250000003994 episode_reward=178.0 running_reward=138.06
# Solved at episode 167!
# frame_count=91631 epsilon=0.12950550000040106 episode_reward=171.0 running_reward=139.83
# Solved at episode 168!
# running reward: 140.23 at episode 168, frame count 92000
# frame_count=92544 epsilon=0.12083200000040506 episode_reward=222.0 running_reward=140.23
# Solved at episode 169!
# frame_count=92665 epsilon=0.11968250000040559 episode_reward=106.0 running_reward=141.28
# Solved at episode 170!
# running reward: 142.61 at episode 170, frame count 93000
# frame_count=93306 epsilon=0.1135930000004084 episode_reward=149.0 running_reward=142.61
# Solved at episode 171!
# frame_count=93688 epsilon=0.10996400000041007 episode_reward=193.0 running_reward=143.38
# Solved at episode 172!
# running reward: 145.23 at episode 172, frame count 94000
# frame_count=94307 epsilon=0.10408350000041278 episode_reward=215.0 running_reward=145.23
# Solved at episode 173!
# frame_count=94525 epsilon=0.10201250000041373 episode_reward=166.0 running_reward=145.65
# Solved at episode 174!
# frame_count=94704 epsilon=0.10031200000041451 episode_reward=154.0 running_reward=145.4
# Solved at episode 175!
# running reward: 145.88 at episode 175, frame count 95000
# frame_count=95343 epsilon=0.09424150000041731 episode_reward=287.0 running_reward=145.88
# Solved at episode 176!
# frame_count=95965 epsilon=0.08833250000042003 episode_reward=203.0 running_reward=149.25
# Solved at episode 177!
# running reward: 151.05 at episode 177, frame count 96000
# frame_count=96282 epsilon=0.08532100000042142 episode_reward=151.0 running_reward=151.05
# Solved at episode 178!
# running reward: 151.78 at episode 178, frame count 97000
# frame_count=97040 epsilon=0.07812000000042474 episode_reward=152.0 running_reward=151.78
# Solved at episode 179!
# frame_count=97390 epsilon=0.07479500000042627 episode_reward=225.0 running_reward=148.62
# Solved at episode 180!
# running reward: 148.55 at episode 180, frame count 98000
# frame_count=98076 epsilon=0.06827800000042927 episode_reward=237.0 running_reward=148.55
# Solved at episode 181!
# frame_count=98258 epsilon=0.06654900000043007 episode_reward=100.0 running_reward=149.83
# Solved at episode 182!
# frame_count=98401 epsilon=0.0651905000004307 episode_reward=114.0 running_reward=149.03
# Solved at episode 183!
# frame_count=98543 epsilon=0.06384150000043132 episode_reward=110.0 running_reward=149.75
# Solved at episode 184!
# frame_count=98770 epsilon=0.061685000000431714 episode_reward=140.0 running_reward=149.94
# Solved at episode 185!
# frame_count=98900 epsilon=0.06045000000043138 episode_reward=102.0 running_reward=149.75
# Solved at episode 186!
# running reward: 151.67 at episode 186, frame count 99000
# frame_count=99167 epsilon=0.0579135000004307 episode_reward=132.0 running_reward=151.67
# Solved at episode 187!
# frame_count=99288 epsilon=0.05676400000043039 episode_reward=110.0 running_reward=151.84
# Solved at episode 188!
# frame_count=99455 epsilon=0.05517750000042996 episode_reward=106.0 running_reward=151.38
# Solved at episode 189!
# running reward: 150.56 at episode 189, frame count 100000
# frame_count=100454 epsilon=0.05 episode_reward=-40.0 running_reward=150.56
# Solved at episode 190!
# running reward: 150.29 at episode 190, frame count 101000
# frame_count=101273 epsilon=0.05 episode_reward=214.0 running_reward=150.29
# Solved at episode 191!
# frame_count=101408 epsilon=0.05 episode_reward=116.0 running_reward=151.05
# Solved at episode 192!
# frame_count=101537 epsilon=0.05 episode_reward=115.0 running_reward=150.11
# Solved at episode 193!
# frame_count=101775 epsilon=0.05 episode_reward=176.0 running_reward=150.49
# Solved at episode 194!
# frame_count=101964 epsilon=0.05 episode_reward=164.0 running_reward=152.81
# Solved at episode 195!
# running reward: 153.66 at episode 195, frame count 102000
# frame_count=102118 epsilon=0.05 episode_reward=99.0 running_reward=153.66
# Solved at episode 196!
# frame_count=102324 epsilon=0.05 episode_reward=166.0 running_reward=153.47
# Solved at episode 197!
# frame_count=102445 epsilon=0.05 episode_reward=109.0 running_reward=154.9
# Solved at episode 198!
# frame_count=102621 epsilon=0.05 episode_reward=166.0 running_reward=154.41
# Solved at episode 199!
# frame_count=102945 epsilon=0.05 episode_reward=216.0 running_reward=155.13
# Solved at episode 200!
# running reward: 155.97 at episode 200, frame count 103000
# frame_count=103099 epsilon=0.05 episode_reward=112.0 running_reward=155.97
# Solved at episode 201!
# frame_count=103245 epsilon=0.05 episode_reward=91.0 running_reward=155.17
# Solved at episode 202!
# frame_count=103335 epsilon=0.05 episode_reward=80.0 running_reward=154.42
# Solved at episode 203!
# frame_count=103547 epsilon=0.05 episode_reward=175.0 running_reward=156.27
# Solved at episode 204!
# frame_count=103734 epsilon=0.05 episode_reward=84.0 running_reward=155.92
# Solved at episode 205!
# running reward: 155.59 at episode 205, frame count 104000
# frame_count=104041 epsilon=0.05 episode_reward=269.0 running_reward=155.59
# Solved at episode 206!
# frame_count=104321 epsilon=0.05 episode_reward=233.0 running_reward=156.63
# Solved at episode 207!
# frame_count=104760 epsilon=0.05 episode_reward=195.0 running_reward=157.77
# Solved at episode 208!
# frame_count=104899 epsilon=0.05 episode_reward=116.0 running_reward=157.46
# Solved at episode 209!
# running reward: 158.70 at episode 209, frame count 105000
# frame_count=105202 epsilon=0.05 episode_reward=189.0 running_reward=158.7
# Solved at episode 210!
# frame_count=105502 epsilon=0.05 episode_reward=234.0 running_reward=157.49
# Solved at episode 211!
# frame_count=105609 epsilon=0.05 episode_reward=98.0 running_reward=158.85
# Solved at episode 212!
# frame_count=105840 epsilon=0.05 episode_reward=146.0 running_reward=157.78
# Solved at episode 213!
# frame_count=105961 epsilon=0.05 episode_reward=110.0 running_reward=157.91
# Solved at episode 214!
# running reward: 155.80 at episode 214, frame count 106000
# frame_count=106077 epsilon=0.05 episode_reward=106.0 running_reward=155.8
# Solved at episode 215!
# frame_count=106180 epsilon=0.05 episode_reward=94.0 running_reward=155.4
# Solved at episode 216!
# frame_count=106312 epsilon=0.05 episode_reward=104.0 running_reward=153.4
# Solved at episode 217!
# running reward: 153.04 at episode 217, frame count 107000
# frame_count=107172 epsilon=0.05 episode_reward=129.0 running_reward=153.04
# Solved at episode 218!
# frame_count=107486 epsilon=0.05 episode_reward=204.0 running_reward=152.53
# Solved at episode 219!
# frame_count=107891 epsilon=0.05 episode_reward=227.0 running_reward=152.87
# Solved at episode 220!
# running reward: 154.22 at episode 220, frame count 108000
# frame_count=108037 epsilon=0.05 episode_reward=66.0 running_reward=154.22
# Solved at episode 221!
# frame_count=108339 epsilon=0.05 episode_reward=185.0 running_reward=153.98
# Solved at episode 222!
# frame_count=108517 epsilon=0.05 episode_reward=101.0 running_reward=153.34
# Solved at episode 223!
# frame_count=108892 epsilon=0.05 episode_reward=275.0 running_reward=152.25
# Solved at episode 224!
# running reward: 153.42 at episode 224, frame count 109000
# frame_count=109272 epsilon=0.05 episode_reward=231.0 running_reward=153.42
# Solved at episode 225!
# frame_count=109531 epsilon=0.05 episode_reward=204.0 running_reward=153.38
# Solved at episode 226!
# frame_count=109829 epsilon=0.05 episode_reward=171.0 running_reward=153.79
# Solved at episode 227!
# running reward: 153.92 at episode 227, frame count 110000
# frame_count=110012 epsilon=0.05 episode_reward=172.0 running_reward=153.92
# Solved at episode 228!
# frame_count=110367 epsilon=0.05 episode_reward=179.0 running_reward=155.82
# Solved at episode 229!
# frame_count=110805 epsilon=0.05 episode_reward=205.0 running_reward=155.92
# Solved at episode 230!
# running reward: 156.96 at episode 230, frame count 111000
# frame_count=111219 epsilon=0.05 episode_reward=176.0 running_reward=156.96
# Solved at episode 231!
# frame_count=111379 epsilon=0.05 episode_reward=116.0 running_reward=156.13
# Solved at episode 232!
# frame_count=111487 epsilon=0.05 episode_reward=92.0 running_reward=156.42
# Solved at episode 233!
# frame_count=111904 epsilon=0.05 episode_reward=143.0 running_reward=155.21
# Solved at episode 234!
# running reward: 155.48 at episode 234, frame count 112000
# frame_count=112091 epsilon=0.05 episode_reward=126.0 running_reward=155.48
# Solved at episode 235!
# frame_count=112219 epsilon=0.05 episode_reward=116.0 running_reward=153.92
# Solved at episode 236!
# frame_count=112334 epsilon=0.05 episode_reward=103.0 running_reward=153.6
# Solved at episode 237!
# frame_count=112759 epsilon=0.05 episode_reward=251.0 running_reward=153.58
# Solved at episode 238!
# frame_count=112922 epsilon=0.05 episode_reward=121.0 running_reward=154.32
# Solved at episode 239!
# running reward: 154.13 at episode 239, frame count 113000
# frame_count=113329 epsilon=0.05 episode_reward=142.0 running_reward=154.13
# Solved at episode 240!
# frame_count=113590 epsilon=0.05 episode_reward=175.0 running_reward=153.66
# Solved at episode 241!
# frame_count=113842 epsilon=0.05 episode_reward=184.0 running_reward=154.12
# Solved at episode 242!
# running reward: 154.95 at episode 242, frame count 114000
# frame_count=114021 epsilon=0.05 episode_reward=161.0 running_reward=154.95
# Solved at episode 243!
# running reward: 154.24 at episode 243, frame count 115000
# frame_count=115020 epsilon=0.05 episode_reward=93.0 running_reward=154.24
# Solved at episode 244!
# frame_count=115228 epsilon=0.05 episode_reward=193.0 running_reward=154.19
# Solved at episode 245!
# frame_count=115346 epsilon=0.05 episode_reward=109.0 running_reward=155.93
# Solved at episode 246!
# frame_count=115462 epsilon=0.05 episode_reward=108.0 running_reward=155.5
# Solved at episode 247!
# frame_count=115570 epsilon=0.05 episode_reward=101.0 running_reward=154.82
# Solved at episode 248!
# frame_count=115680 epsilon=0.05 episode_reward=99.0 running_reward=154.53
# Solved at episode 249!
# frame_count=115896 epsilon=0.05 episode_reward=158.0 running_reward=154.44
# Solved at episode 250!
# running reward: 154.93 at episode 250, frame count 116000
# frame_count=116650 epsilon=0.05 episode_reward=133.0 running_reward=154.93
# Solved at episode 251!
# frame_count=116848 epsilon=0.05 episode_reward=175.0 running_reward=153.59
# Solved at episode 252!
# running reward: 153.82 at episode 252, frame count 117000
# frame_count=117075 epsilon=0.05 episode_reward=173.0 running_reward=153.82
# Solved at episode 253!
# frame_count=117335 epsilon=0.05 episode_reward=165.0 running_reward=154.5
# Solved at episode 254!
# frame_count=117595 epsilon=0.05 episode_reward=176.0 running_reward=152.78
# Solved at episode 255!
# frame_count=117871 epsilon=0.05 episode_reward=184.0 running_reward=152.51
# Solved at episode 256!
# running reward: 153.35 at episode 256, frame count 118000
# frame_count=118167 epsilon=0.05 episode_reward=209.0 running_reward=153.35
# Solved at episode 257!
# frame_count=118405 epsilon=0.05 episode_reward=198.0 running_reward=154.17
# Solved at episode 258!
# frame_count=118748 epsilon=0.05 episode_reward=138.0 running_reward=154.97
# Solved at episode 259!
# frame_count=118857 epsilon=0.05 episode_reward=98.0 running_reward=153.94
# Solved at episode 260!
# frame_count=118989 epsilon=0.05 episode_reward=120.0 running_reward=153.9
# Solved at episode 261!
# running reward: 154.05 at episode 261, frame count 119000
# frame_count=119459 epsilon=0.05 episode_reward=271.0 running_reward=154.05
# Solved at episode 262!
# frame_count=119702 epsilon=0.05 episode_reward=218.0 running_reward=155.06
# Solved at episode 263!
# frame_count=119955 epsilon=0.05 episode_reward=178.0 running_reward=155.61
# Solved at episode 264!
# running reward: 155.89 at episode 264, frame count 120000
# frame_count=120086 epsilon=0.05 episode_reward=122.0 running_reward=155.89
# Solved at episode 265!
# frame_count=120201 epsilon=0.05 episode_reward=105.0 running_reward=154.92
# Solved at episode 266!
# frame_count=120337 epsilon=0.05 episode_reward=127.0 running_reward=154.39
# Solved at episode 267!
# frame_count=120483 epsilon=0.05 episode_reward=130.0 running_reward=153.88
# Solved at episode 268!
# running reward: 153.47 at episode 268, frame count 121000
# frame_count=121482 epsilon=0.05 episode_reward=-22.0 running_reward=153.47
# Solved at episode 269!
# frame_count=121618 epsilon=0.05 episode_reward=127.0 running_reward=151.03
# Solved at episode 270!
# frame_count=121778 epsilon=0.05 episode_reward=128.0 running_reward=151.24
# Solved at episode 271!
# frame_count=121924 epsilon=0.05 episode_reward=128.0 running_reward=151.03
# Solved at episode 272!
# running reward: 150.38 at episode 272, frame count 122000
# frame_count=122015 epsilon=0.05 episode_reward=82.0 running_reward=150.38
# Solved at episode 273!
# running reward: 149.05 at episode 273, frame count 123000
# frame_count=123014 epsilon=0.05 episode_reward=-1.0 running_reward=149.05
# Solved at episode 274!
# frame_count=123146 epsilon=0.05 episode_reward=113.0 running_reward=147.38
# Solved at episode 275!
# frame_count=123264 epsilon=0.05 episode_reward=102.0 running_reward=146.97
# Solved at episode 276!
# running reward: 145.12 at episode 276, frame count 124000
# frame_count=124145 epsilon=0.05 episode_reward=424.0 running_reward=145.12
# Solved at episode 277!
# frame_count=124275 epsilon=0.05 episode_reward=120.0 running_reward=147.33
# Solved at episode 278!
# frame_count=124418 epsilon=0.05 episode_reward=107.0 running_reward=147.02
# Solved at episode 279!
# frame_count=124590 epsilon=0.05 episode_reward=154.0 running_reward=146.57
# Solved at episode 280!
# frame_count=124777 epsilon=0.05 episode_reward=171.0 running_reward=145.86
# Solved at episode 281!
# frame_count=124926 epsilon=0.05 episode_reward=107.0 running_reward=145.2
# Solved at episode 282!
# running reward: 145.27 at episode 282, frame count 125000
# frame_count=125084 epsilon=0.05 episode_reward=134.0 running_reward=145.27
# Solved at episode 283!
# frame_count=125213 epsilon=0.05 episode_reward=119.0 running_reward=145.47
# Solved at episode 284!
# frame_count=125326 epsilon=0.05 episode_reward=103.0 running_reward=145.56
# Solved at episode 285!
# frame_count=125598 epsilon=0.05 episode_reward=181.0 running_reward=145.19
# Solved at episode 286!
# frame_count=125732 epsilon=0.05 episode_reward=123.0 running_reward=145.98
# Solved at episode 287!
# frame_count=125881 epsilon=0.05 episode_reward=130.0 running_reward=145.89
# Solved at episode 288!
# running reward: 146.09 at episode 288, frame count 126000
# frame_count=126011 epsilon=0.05 episode_reward=106.0 running_reward=146.09
# Solved at episode 289!
# frame_count=126269 epsilon=0.05 episode_reward=229.0 running_reward=146.09
# Solved at episode 290!
# frame_count=126560 epsilon=0.05 episode_reward=198.0 running_reward=148.78
# Solved at episode 291!
# running reward: 148.62 at episode 291, frame count 127000
# frame_count=127559 epsilon=0.05 episode_reward=27.0 running_reward=148.62
# Solved at episode 292!
# running reward: 147.73 at episode 292, frame count 128000
# frame_count=128005 epsilon=0.05 episode_reward=303.0 running_reward=147.73
# Solved at episode 293!
# frame_count=128220 epsilon=0.05 episode_reward=151.0 running_reward=149.61
# Solved at episode 294!
# frame_count=128596 epsilon=0.05 episode_reward=183.0 running_reward=149.36
# Solved at episode 295!
# running reward: 149.55 at episode 295, frame count 129000
# frame_count=129595 epsilon=0.05 episode_reward=108.0 running_reward=149.55
# Solved at episode 296!
# frame_count=129745 epsilon=0.05 episode_reward=139.0 running_reward=149.64
# Solved at episode 297!
# frame_count=129962 epsilon=0.05 episode_reward=157.0 running_reward=149.37
# Solved at episode 298!
# running reward: 149.85 at episode 298, frame count 130000
# frame_count=130243 epsilon=0.05 episode_reward=201.0 running_reward=149.85
# Solved at episode 299!
# frame_count=130465 epsilon=0.05 episode_reward=170.0 running_reward=150.2
# Solved at episode 300!
# frame_count=130925 epsilon=0.05 episode_reward=258.0 running_reward=149.74
# Solved at episode 301!
# running reward: 151.20 at episode 301, frame count 131000
# frame_count=131073 epsilon=0.05 episode_reward=132.0 running_reward=151.2
# Solved at episode 302!
# frame_count=131180 epsilon=0.05 episode_reward=99.0 running_reward=151.61
# Solved at episode 303!
# frame_count=131316 epsilon=0.05 episode_reward=126.0 running_reward=151.8
# Solved at episode 304!
# frame_count=131636 epsilon=0.05 episode_reward=218.0 running_reward=151.31
# Solved at episode 305!
# running reward: 152.65 at episode 305, frame count 132000
# frame_count=132635 epsilon=0.05 episode_reward=8.0 running_reward=152.65
# Solved at episode 306!
# running reward: 150.04 at episode 306, frame count 133000
# frame_count=133634 epsilon=0.05 episode_reward=114.0 running_reward=150.04
# Solved at episode 307!
# frame_count=133742 epsilon=0.05 episode_reward=98.0 running_reward=148.85
# Solved at episode 308!
# frame_count=133859 epsilon=0.05 episode_reward=100.0 running_reward=147.88
# Solved at episode 309!
# frame_count=133992 epsilon=0.05 episode_reward=123.0 running_reward=147.72
# Solved at episode 310!
# running reward: 147.06 at episode 310, frame count 134000
# frame_count=134350 epsilon=0.05 episode_reward=189.0 running_reward=147.06
# Solved at episode 311!
# frame_count=134502 epsilon=0.05 episode_reward=138.0 running_reward=146.61
# Solved at episode 312!
# frame_count=134626 epsilon=0.05 episode_reward=115.0 running_reward=147.01
# Solved at episode 313!
# frame_count=134763 epsilon=0.05 episode_reward=126.0 running_reward=146.7
# Solved at episode 314!
# frame_count=134850 epsilon=0.05 episode_reward=78.0 running_reward=146.86
# Solved at episode 315!
# running reward: 146.58 at episode 315, frame count 135000
# frame_count=135095 epsilon=0.05 episode_reward=190.0 running_reward=146.58
# Solved at episode 316!
# running reward: 147.54 at episode 316, frame count 136000
# frame_count=136094 epsilon=0.05 episode_reward=194.0 running_reward=147.54
# Solved at episode 317!
# frame_count=136251 epsilon=0.05 episode_reward=117.0 running_reward=148.44
# Solved at episode 318!
# frame_count=136372 epsilon=0.05 episode_reward=108.0 running_reward=148.32
# Solved at episode 319!
# running reward: 147.36 at episode 319, frame count 137000
# frame_count=137358 epsilon=0.05 episode_reward=110.0 running_reward=147.36
# Solved at episode 320!
# frame_count=137501 epsilon=0.05 episode_reward=126.0 running_reward=146.19
# Solved at episode 321!
# frame_count=137671 epsilon=0.05 episode_reward=152.0 running_reward=146.79
# Solved at episode 322!
# running reward: 146.46 at episode 322, frame count 138000
# frame_count=138154 epsilon=0.05 episode_reward=177.0 running_reward=146.46
# Solved at episode 323!
# frame_count=138557 epsilon=0.05 episode_reward=230.0 running_reward=147.22
# Solved at episode 324!
# frame_count=138739 epsilon=0.05 episode_reward=116.0 running_reward=146.77
# Solved at episode 325!
# frame_count=138885 epsilon=0.05 episode_reward=134.0 running_reward=145.62
# Solved at episode 326!
# running reward: 144.92 at episode 326, frame count 139000
# frame_count=139010 epsilon=0.05 episode_reward=113.0 running_reward=144.92
# Solved at episode 327!
# frame_count=139348 epsilon=0.05 episode_reward=203.0 running_reward=144.34
# Solved at episode 328!
# running reward: 144.65 at episode 328, frame count 140000
# frame_count=140031 epsilon=0.05 episode_reward=152.0 running_reward=144.65
# Solved at episode 329!
# frame_count=140267 epsilon=0.05 episode_reward=113.0 running_reward=144.38
# Solved at episode 330!
# frame_count=140428 epsilon=0.05 episode_reward=115.0 running_reward=143.46
# Solved at episode 331!
# frame_count=140582 epsilon=0.05 episode_reward=132.0 running_reward=142.85
# Solved at episode 332!
# frame_count=140857 epsilon=0.05 episode_reward=187.0 running_reward=143.01
# Solved at episode 333!
# running reward: 143.96 at episode 333, frame count 141000
# frame_count=141048 epsilon=0.05 episode_reward=152.0 running_reward=143.96
# Solved at episode 334!
# frame_count=141338 epsilon=0.05 episode_reward=197.0 running_reward=144.05
# Solved at episode 335!
# frame_count=141474 epsilon=0.05 episode_reward=122.0 running_reward=144.76
# Solved at episode 336!
# frame_count=141616 epsilon=0.05 episode_reward=129.0 running_reward=144.82
# Solved at episode 337!
# running reward: 145.08 at episode 337, frame count 142000
# frame_count=142051 epsilon=0.05 episode_reward=146.0 running_reward=145.08
# Solved at episode 338!
# frame_count=142431 epsilon=0.05 episode_reward=227.0 running_reward=144.03
# Solved at episode 339!
# frame_count=142569 epsilon=0.05 episode_reward=123.0 running_reward=145.09
# Solved at episode 340!
# running reward: 144.90 at episode 340, frame count 143000
# frame_count=143124 epsilon=0.05 episode_reward=247.0 running_reward=144.9
# Solved at episode 341!
# frame_count=143666 epsilon=0.05 episode_reward=159.0 running_reward=145.62
# Solved at episode 342!
# running reward: 145.37 at episode 342, frame count 144000
# frame_count=144383 epsilon=0.05 episode_reward=188.0 running_reward=145.37
# Solved at episode 343!
# frame_count=144515 epsilon=0.05 episode_reward=114.0 running_reward=145.64
# Solved at episode 344!
# frame_count=144646 epsilon=0.05 episode_reward=122.0 running_reward=145.85
# Solved at episode 345!
# frame_count=144948 epsilon=0.05 episode_reward=212.0 running_reward=145.14
# Solved at episode 346!
# running reward: 146.17 at episode 346, frame count 145000
# frame_count=145075 epsilon=0.05 episode_reward=113.0 running_reward=146.17
# Solved at episode 347!
# frame_count=145190 epsilon=0.05 episode_reward=108.0 running_reward=146.22
# Solved at episode 348!
# running reward: 146.29 at episode 348, frame count 146000
# frame_count=146189 epsilon=0.05 episode_reward=1.0 running_reward=146.29
# Solved at episode 349!
# frame_count=146326 epsilon=0.05 episode_reward=124.0 running_reward=145.31
# Solved at episode 350!
# frame_count=146546 epsilon=0.05 episode_reward=145.0 running_reward=144.97
# Solved at episode 351!
# running reward: 145.09 at episode 351, frame count 147000
# frame_count=147545 epsilon=0.05 episode_reward=-38.0 running_reward=145.09
# Solved at episode 352!
# running reward: 142.96 at episode 352, frame count 148000
# frame_count=148544 epsilon=0.05 episode_reward=173.0 running_reward=142.96
# Solved at episode 353!
# frame_count=148680 epsilon=0.05 episode_reward=124.0 running_reward=142.96
# Solved at episode 354!
# running reward: 142.55 at episode 354, frame count 149000
# frame_count=149007 epsilon=0.05 episode_reward=178.0 running_reward=142.55
# Solved at episode 355!
# frame_count=149311 epsilon=0.05 episode_reward=234.0 running_reward=142.57
# ...
# Solved at episode 485!
# frame_count=193434 epsilon=0.05 episode_reward=147.0 running_reward=172.29
# Solved at episode 486!
# frame_count=193616 epsilon=0.05 episode_reward=164.0 running_reward=171.44
# Solved at episode 487!
# frame_count=193971 epsilon=0.05 episode_reward=233.0 running_reward=171.78
# Solved at episode 488!
# running reward: 172.38 at episode 488, frame count 194000
# frame_count=194098 epsilon=0.05 episode_reward=103.0 running_reward=172.38
# Solved at episode 489!
# frame_count=194488 epsilon=0.05 episode_reward=254.0 running_reward=172.07
# Solved at episode 490!
# frame_count=194869 epsilon=0.05 episode_reward=253.0 running_reward=173.78
# Solved at episode 491!
# running reward: 175.15 at episode 491, frame count 195000
# frame_count=195578 epsilon=0.05 episode_reward=310.0 running_reward=175.15
# Solved at episode 492!
# frame_count=195748 epsilon=0.05 episode_reward=148.0 running_reward=177.15
# Solved at episode 493!
# frame_count=195891 epsilon=0.05 episode_reward=130.0 running_reward=177.62
# Solved at episode 494!
# running reward: 177.74 at episode 494, frame count 196000
# frame_count=196503 epsilon=0.05 episode_reward=188.0 running_reward=177.74
# Solved at episode 495!
# running reward: 177.32 at episode 495, frame count 197000
# frame_count=197246 epsilon=0.05 episode_reward=188.0 running_reward=177.32
# Solved at episode 496!
# frame_count=197449 epsilon=0.05 episode_reward=158.0 running_reward=176.99
# Solved at episode 497!
# frame_count=197635 epsilon=0.05 episode_reward=160.0 running_reward=175.95
# Solved at episode 498!
# frame_count=197933 epsilon=0.05 episode_reward=199.0 running_reward=176.32
# Solved at episode 499!
# running reward: 176.99 at episode 499, frame count 198000
# frame_count=198138 epsilon=0.05 episode_reward=189.0 running_reward=176.99
# Solved at episode 500!
# frame_count=198533 epsilon=0.05 episode_reward=258.0 running_reward=177.62
# Solved at episode 501!
# frame_count=198680 epsilon=0.05 episode_reward=138.0 running_reward=178.12
# Solved at episode 502!
# frame_count=198835 epsilon=0.05 episode_reward=117.0 running_reward=179.52
# Solved at episode 503!
# frame_count=198991 epsilon=0.05 episode_reward=141.0 running_reward=179.65
# Solved at episode 504!
# running reward: 180.01 at episode 504, frame count 199000
# frame_count=199101 epsilon=0.05 episode_reward=100.0 running_reward=180.01
# Solved at episode 505!
# frame_count=199247 epsilon=0.05 episode_reward=108.0 running_reward=179.96
# Solved at episode 506!
# frame_count=199374 epsilon=0.05 episode_reward=119.0 running_reward=179.7
# Solved at episode 507!
# frame_count=199906 epsilon=0.05 episode_reward=260.0 running_reward=180.3
# Solved at episode 508!
# running reward: 180.88 at episode 508, frame count 200000
# frame_count=200050 epsilon=0.05 episode_reward=134.0 running_reward=180.88
# Solved at episode 509!
# frame_count=200193 epsilon=0.05 episode_reward=120.0 running_reward=180.83
# Solved at episode 510!
# frame_count=200613 epsilon=0.05 episode_reward=200.0 running_reward=179.9
# Solved at episode 511!
# frame_count=200773 epsilon=0.05 episode_reward=142.0 running_reward=180.82
# Solved at episode 512!
# running reward: 181.04 at episode 512, frame count 201000
# frame_count=201065 epsilon=0.05 episode_reward=255.0 running_reward=181.04
# Solved at episode 513!
# running reward: 182.48 at episode 513, frame count 202000
# frame_count=202064 epsilon=0.05 episode_reward=269.0 running_reward=182.48
# Solved at episode 514!
# frame_count=202218 epsilon=0.05 episode_reward=143.0 running_reward=184.4
# Solved at episode 515!
# frame_count=202346 epsilon=0.05 episode_reward=115.0 running_reward=184.06
# Solved at episode 516!
# frame_count=202578 epsilon=0.05 episode_reward=178.0 running_reward=183.87
# Solved at episode 517!
# frame_count=202727 epsilon=0.05 episode_reward=132.0 running_reward=184.52
# Solved at episode 518!
# running reward: 182.95 at episode 518, frame count 203000
# frame_count=203043 epsilon=0.05 episode_reward=236.0 running_reward=182.95
# Solved at episode 519!
# frame_count=203173 epsilon=0.05 episode_reward=119.0 running_reward=184.16
# Solved at episode 520!
# frame_count=203376 epsilon=0.05 episode_reward=190.0 running_reward=182.62
# Solved at episode 521!
# frame_count=203514 epsilon=0.05 episode_reward=126.0 running_reward=182.68
# Solved at episode 522!
# frame_count=203643 epsilon=0.05 episode_reward=120.0 running_reward=181.94
# Solved at episode 523!
# frame_count=203751 epsilon=0.05 episode_reward=98.0 running_reward=181.93
# Solved at episode 524!
# running reward: 179.91 at episode 524, frame count 204000
# frame_count=204519 epsilon=0.05 episode_reward=263.0 running_reward=179.91
# Solved at episode 525!
# frame_count=204774 epsilon=0.05 episode_reward=181.0 running_reward=181.22
# Solved at episode 526!
# running reward: 181.10 at episode 526, frame count 205000
# frame_count=205221 epsilon=0.05 episode_reward=221.0 running_reward=181.1
# Solved at episode 527!
# frame_count=205504 epsilon=0.05 episode_reward=217.0 running_reward=181.25
# Solved at episode 528!
# frame_count=205618 epsilon=0.05 episode_reward=105.0 running_reward=182.42
# Solved at episode 529!
# running reward: 181.08 at episode 529, frame count 206000
# frame_count=206000 epsilon=0.05 episode_reward=339.0 running_reward=181.08
# Solved at episode 530!
# frame_count=206161 epsilon=0.05 episode_reward=141.0 running_reward=182.52
# Solved at episode 531!
# frame_count=206510 epsilon=0.05 episode_reward=243.0 running_reward=181.82
# Solved at episode 532!
# frame_count=206763 epsilon=0.05 episode_reward=224.0 running_reward=182.7
# Solved at episode 533!
# running reward: 183.77 at episode 533, frame count 207000
# frame_count=207043 epsilon=0.05 episode_reward=215.0 running_reward=183.77
# Solved at episode 534!
# frame_count=207525 epsilon=0.05 episode_reward=288.0 running_reward=183.71
# Solved at episode 535!
# frame_count=207943 epsilon=0.05 episode_reward=308.0 running_reward=183.88
# Solved at episode 536!
# running reward: 185.56 at episode 536, frame count 208000
# frame_count=208111 epsilon=0.05 episode_reward=138.0 running_reward=185.56
# Solved at episode 537!
# frame_count=208544 epsilon=0.05 episode_reward=255.0 running_reward=185.13
# Solved at episode 538!
# frame_count=208713 epsilon=0.05 episode_reward=146.0 running_reward=186.51
# Solved at episode 539!
# frame_count=208871 epsilon=0.05 episode_reward=145.0 running_reward=186.87
# Solved at episode 540!
# running reward: 186.40 at episode 540, frame count 209000
# frame_count=209290 epsilon=0.05 episode_reward=183.0 running_reward=186.4
# Solved at episode 541!
# frame_count=209430 epsilon=0.05 episode_reward=130.0 running_reward=186.64
# Solved at episode 542!
# frame_count=209576 epsilon=0.05 episode_reward=133.0 running_reward=186.35
# Solved at episode 543!
# frame_count=209818 epsilon=0.05 episode_reward=211.0 running_reward=184.18
# Solved at episode 544!
# running reward: 185.38 at episode 544, frame count 210000
# frame_count=210144 epsilon=0.05 episode_reward=251.0 running_reward=185.38
# Solved at episode 545!
# frame_count=210406 epsilon=0.05 episode_reward=236.0 running_reward=186.8
# Solved at episode 546!
# frame_count=210543 epsilon=0.05 episode_reward=124.0 running_reward=187.82
# Solved at episode 547!
# frame_count=210800 epsilon=0.05 episode_reward=201.0 running_reward=187.18
# Solved at episode 548!
# running reward: 185.76 at episode 548, frame count 211000
# frame_count=211501 epsilon=0.05 episode_reward=351.0 running_reward=185.76
# Solved at episode 549!
# frame_count=211616 epsilon=0.05 episode_reward=104.0 running_reward=187.6
# Solved at episode 550!
# frame_count=211740 epsilon=0.05 episode_reward=116.0 running_reward=187.14
# Solved at episode 551!
# frame_count=211951 epsilon=0.05 episode_reward=195.0 running_reward=186.99
# Solved at episode 552!
# running reward: 186.94 at episode 552, frame count 212000
# frame_count=212063 epsilon=0.05 episode_reward=103.0 running_reward=186.94
# Solved at episode 553!
# frame_count=212614 epsilon=0.05 episode_reward=383.0 running_reward=185.38
# Solved at episode 554!
# running reward: 188.17 at episode 554, frame count 213000
# frame_count=213059 epsilon=0.05 episode_reward=195.0 running_reward=188.17
# Solved at episode 555!
# frame_count=213644 epsilon=0.05 episode_reward=214.0 running_reward=188.91
# Solved at episode 556!
# frame_count=213873 epsilon=0.05 episode_reward=203.0 running_reward=189.8
# Solved at episode 557!
# running reward: 190.66 at episode 557, frame count 214000
# frame_count=214523 epsilon=0.05 episode_reward=202.0 running_reward=190.66
# Solved at episode 558!
# frame_count=214797 epsilon=0.05 episode_reward=176.0 running_reward=189.31
# Solved at episode 559!
# running reward: 190.07 at episode 559, frame count 215000
# frame_count=215796 epsilon=0.05 episode_reward=140.0 running_reward=190.07
# Solved at episode 560!
# running reward: 189.21 at episode 560, frame count 216000
# frame_count=216023 epsilon=0.05 episode_reward=214.0 running_reward=189.21
# Solved at episode 561!
# running reward: 189.15 at episode 561, frame count 217000
# frame_count=217022 epsilon=0.05 episode_reward=247.0 running_reward=189.15
# Solved at episode 562!
# frame_count=217368 epsilon=0.05 episode_reward=252.0 running_reward=188.85
# Solved at episode 563!
# frame_count=217859 epsilon=0.05 episode_reward=330.0 running_reward=188.43
# Solved at episode 564!
# running reward: 189.97 at episode 564, frame count 218000
# frame_count=218793 epsilon=0.05 episode_reward=464.0 running_reward=189.97
# Solved at episode 565!
# running reward: 191.21 at episode 565, frame count 219000
# frame_count=219026 epsilon=0.05 episode_reward=216.0 running_reward=191.21
# Solved at episode 566!
# frame_count=219167 epsilon=0.05 episode_reward=132.0 running_reward=192.31
# Solved at episode 567!
# frame_count=219400 epsilon=0.05 episode_reward=211.0 running_reward=190.67
# Solved at episode 568!
# frame_count=219903 epsilon=0.05 episode_reward=263.0 running_reward=189.66
# Solved at episode 569!
# running reward: 190.08 at episode 569, frame count 220000
# frame_count=220065 epsilon=0.05 episode_reward=149.0 running_reward=190.08
# Solved at episode 570!
# frame_count=220559 epsilon=0.05 episode_reward=192.0 running_reward=190.23
# Solved at episode 571!
# frame_count=220709 epsilon=0.05 episode_reward=134.0 running_reward=190.78
# Solved at episode 572!
# running reward: 190.01 at episode 572, frame count 221000
# frame_count=221005 epsilon=0.05 episode_reward=176.0 running_reward=190.01
# Solved at episode 573!
# frame_count=221537 epsilon=0.05 episode_reward=273.0 running_reward=189.63
# Solved at episode 574!
# running reward: 190.52 at episode 574, frame count 222000
# frame_count=222061 epsilon=0.05 episode_reward=184.0 running_reward=190.52
# Solved at episode 575!
# frame_count=222259 epsilon=0.05 episode_reward=118.0 running_reward=191.03
# Solved at episode 576!
# frame_count=222634 epsilon=0.05 episode_reward=239.0 running_reward=192.22
# Solved at episode 577!
# frame_count=222801 epsilon=0.05 episode_reward=146.0 running_reward=192.78
# Solved at episode 578!
# frame_count=222914 epsilon=0.05 episode_reward=103.0 running_reward=193.22
# Solved at episode 579!
# running reward: 192.03 at episode 579, frame count 223000
# frame_count=223247 epsilon=0.05 episode_reward=232.0 running_reward=192.03
# Solved at episode 580!
# frame_count=223696 epsilon=0.05 episode_reward=296.0 running_reward=192.79
# Solved at episode 581!
# frame_count=223979 epsilon=0.05 episode_reward=204.0 running_reward=193.63
# Solved at episode 582!
# running reward: 194.25 at episode 582, frame count 224000
# frame_count=224624 epsilon=0.05 episode_reward=273.0 running_reward=194.25
# Solved at episode 583!
# frame_count=224782 epsilon=0.05 episode_reward=137.0 running_reward=193.97
# Solved at episode 584!
# frame_count=224930 epsilon=0.05 episode_reward=133.0 running_reward=193.21
# Solved at episode 585!
# running reward: 192.40 at episode 585, frame count 225000
# frame_count=225098 epsilon=0.05 episode_reward=138.0 running_reward=192.4
# Solved at episode 586!
# frame_count=225390 epsilon=0.05 episode_reward=260.0 running_reward=192.31
# Solved at episode 587!
# frame_count=225549 epsilon=0.05 episode_reward=145.0 running_reward=193.27
# Solved at episode 588!
# frame_count=225670 epsilon=0.05 episode_reward=113.0 running_reward=192.39
# Solved at episode 589!
# frame_count=225857 epsilon=0.05 episode_reward=111.0 running_reward=192.49
# Solved at episode 590!
# running reward: 191.06 at episode 590, frame count 226000
# frame_count=226299 epsilon=0.05 episode_reward=204.0 running_reward=191.06
# Solved at episode 591!
# frame_count=226396 epsilon=0.05 episode_reward=88.0 running_reward=190.57
# Solved at episode 592!
# frame_count=226695 epsilon=0.05 episode_reward=228.0 running_reward=188.35
# Solved at episode 593!
# frame_count=226827 epsilon=0.05 episode_reward=124.0 running_reward=189.15
# Solved at episode 594!
# frame_count=226970 epsilon=0.05 episode_reward=131.0 running_reward=189.09
# Solved at episode 595!
# running reward: 188.52 at episode 595, frame count 227000
# frame_count=227109 epsilon=0.05 episode_reward=128.0 running_reward=188.52
# Solved at episode 596!
# frame_count=227398 epsilon=0.05 episode_reward=210.0 running_reward=187.92
# Solved at episode 597!
# frame_count=227557 epsilon=0.05 episode_reward=147.0 running_reward=188.44
# Solved at episode 598!
# frame_count=227696 epsilon=0.05 episode_reward=128.0 running_reward=188.31
# Solved at episode 599!
# frame_count=227784 epsilon=0.05 episode_reward=78.0 running_reward=187.6
# Solved at episode 600!
# frame_count=227944 epsilon=0.05 episode_reward=135.0 running_reward=186.49
# Solved at episode 601!
# running reward: 185.26 at episode 601, frame count 228000
# frame_count=228241 epsilon=0.05 episode_reward=196.0 running_reward=185.26
# Solved at episode 602!
# frame_count=228389 epsilon=0.05 episode_reward=132.0 running_reward=185.84
# Solved at episode 603!
# frame_count=228659 epsilon=0.05 episode_reward=222.0 running_reward=185.99
# Solved at episode 604!
# frame_count=228958 epsilon=0.05 episode_reward=204.0 running_reward=186.8
# Solved at episode 605!
# running reward: 187.84 at episode 605, frame count 229000
# frame_count=229250 epsilon=0.05 episode_reward=240.0 running_reward=187.84
# Solved at episode 606!
# frame_count=229449 epsilon=0.05 episode_reward=144.0 running_reward=189.16
# Solved at episode 607!
# frame_count=229612 epsilon=0.05 episode_reward=141.0 running_reward=189.41
# Solved at episode 608!
# frame_count=229999 epsilon=0.05 episode_reward=262.0 running_reward=188.22
# Solved at episode 609!
# running reward: 189.50 at episode 609, frame count 230000
# frame_count=230241 epsilon=0.05 episode_reward=211.0 running_reward=189.5
# Solved at episode 610!
# frame_count=230494 epsilon=0.05 episode_reward=222.0 running_reward=190.41
# Solved at episode 611!
# frame_count=230669 epsilon=0.05 episode_reward=145.0 running_reward=190.63
# Solved at episode 612!
# running reward: 190.66 at episode 612, frame count 231000
# frame_count=231034 epsilon=0.05 episode_reward=263.0 running_reward=190.66
# Solved at episode 613!
# frame_count=231173 epsilon=0.05 episode_reward=119.0 running_reward=190.74
# Solved at episode 614!
# frame_count=231469 epsilon=0.05 episode_reward=201.0 running_reward=189.24
# Solved at episode 615!
# frame_count=231609 epsilon=0.05 episode_reward=120.0 running_reward=189.82
# Solved at episode 616!
# frame_count=231740 epsilon=0.05 episode_reward=120.0 running_reward=189.87
# Solved at episode 617!
# frame_count=231901 epsilon=0.05 episode_reward=146.0 running_reward=189.29
# Solved at episode 618!
# running reward: 189.43 at episode 618, frame count 232000
# frame_count=232464 epsilon=0.05 episode_reward=197.0 running_reward=189.43
# Solved at episode 619!
# frame_count=232602 epsilon=0.05 episode_reward=125.0 running_reward=189.04
# Solved at episode 620!
# frame_count=232766 epsilon=0.05 episode_reward=151.0 running_reward=189.1
# Solved at episode 621!
# frame_count=232907 epsilon=0.05 episode_reward=126.0 running_reward=188.71
# Solved at episode 622!
# running reward: 188.71 at episode 622, frame count 233000
# frame_count=233813 epsilon=0.05 episode_reward=246.0 running_reward=188.71
# Solved at episode 623!
# frame_count=233936 epsilon=0.05 episode_reward=106.0 running_reward=189.97
# Solved at episode 624!
